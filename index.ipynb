# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %%
cur.execute("""SELEct count(*) from employees;""").fetchall()
# Out:
# [(23,)]

# %%
cur.execute("""SELECT firstname, lastname, city, state FROM employees lEFT JOIN offices ON employees.officeCode = offices.officeCode;""")
df = pd.DataFrame(cur.fetchall())

# %%
len(df)
# Out:
# 23

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
cur.execute("""SELECT customerName, orderNumber, orderDate, status FROM customers lEFT JOIN orders ON customers.customerNumber = orders.customerNumber GROUP BY 1;""")
df = pd.DataFrame(cur.fetchall())
df
# Out:
#                                       0      1           2           3
# 0                         ANG Resellers   None        None        None
# 1                        AV Stores, Co.  10332  2004-11-17     Shipped
# 2                          Alpha Cognac  10397  2005-03-28     Shipped
# 3                American Souvenirs Inc   None        None        None
# 4                    Amica Models & Co.  10293  2004-09-09     Shipped
# 5               Anna's Decorations, Ltd  10391  2005-03-09     Shipped
# 6                   Anton Designs, Ltd.   None        None        None
# 7            Asian Shopping Network, Co   None        None        None
# 8                 Asian Treasures, Inc.   None        None        None
# 9                     Atelier graphique  10345  2004-11-25     Shipped
# 10         Australian Collectables, Ltd  10415  2005-05-09    Disputed
# 11           Australian Collectors, Co.  10347  2004-11-29     Shipped
# ...

# %%
len(df)
# Out:
# 122

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
cur.execute("""SELECT * FROM orders JOIN orderdetails USING(orderNumber);""")
df = pd.DataFrame(cur.fetchall())

# %%
df
# Out:
#          0           1           2           3           4   \
# 0     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 1     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 2     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 3     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 4     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 5     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 6     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 7     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 8     10102  2003-01-10  2003-01-18  2003-01-14     Shipped
# 9     10102  2003-01-10  2003-01-18  2003-01-14     Shipped
# 10    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# 11    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# 12    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# 13    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# 14    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and all the product information for each product in the order.

# %%
cur.execute("""SELECT * FROM orders JOIN orderdetails On orders.orderNumber = orderdetails.orderNumber Join products On orderdetails.productCode=products.productCode;""")
df = pd.DataFrame(cur.fetchall())

# %%
df.head()
# Out:
#       0           1           2           3        4                       5   \
# 0  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 1  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 2  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 3  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 4  10101  2003-01-09  2003-01-18  2003-01-11  Shipped  Check on availability.
#
#     6      7         8   9    ...   11        12  \
# 0  363  10100  S18_1749  30   ...    3  S18_1749
# 1  363  10100  S18_2248  50   ...    2  S18_2248
# 2  363  10100  S18_4409  22   ...    4  S18_4409
# 3  363  10100  S24_3969  49   ...    1  S24_3969
# 4  128  10101  S18_2325  25   ...    4  S18_2325
#
#                                     13            14    15  \
# 0             1917 Grand Touring Sedan  Vintage Cars  1:18
# 1                   1911 Ford Town Car  Vintage Cars  1:18
# 2  1932 Alfa Romeo 8C2300 Spider Sport  Vintage Cars  1:18
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
